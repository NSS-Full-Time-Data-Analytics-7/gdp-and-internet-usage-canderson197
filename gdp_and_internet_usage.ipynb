# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline 
#so that we don't have to put plt.show() every time

# %% [markdown]
# 5.	Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called `gdp_df`. Take a look at the first 6 rows.
# 98. Look at the shape of each DataFrame - how many rows? How many columns?
# 6.	Take a look at the datatypes for the columns in each DataFrame.
# 99. Take a look at the last 10 rows of each DataFrame in turn.

# %%
gdp_df = pd.read_csv('data/gdp_percapita.csv')
gdp_df.head(6)
#there is an argument in read_csv that allows you to read in only a certain number of rows, this would be the fix for the footnotes at the bottom of the csv
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN

# %%
gdp_df.shape
# Out:
# (6868, 4)

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6858        Zimbabwe  1999  3600.849291              NaN
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %% [markdown]
# 6. Repeat for the internet use dataset. Call this DataFrame `internet_df`. Take a look at the first six rows.
# 98. Look at the shape of each DataFrame - how many rows? How many columns?
# 6.	Take a look at the datatypes for the columns in each DataFrame.
# 99. Take a look at the last 10 rows of each DataFrame in turn.

# %%
internet_df = pd.read_csv('data/internet_use.csv')
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
internet_df.shape
# Out:
# (4495, 4)

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# 7.	Drop the `value footnotes` column from both DataFrames. Check that this worked as expected.

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2019  2065.036398
# 1        Afghanistan  2018  2033.779002
# 2        Afghanistan  2017  2058.383832
# 3        Afghanistan  2016  2057.062164
# 4        Afghanistan  2015  2068.265904
# ...              ...   ...          ...
# 6863        Zimbabwe  1994  3263.934978
# 6864        Zimbabwe  1993  3033.504852
# 6865        Zimbabwe  1992  3054.889178
# 6866        Zimbabwe  1991  3426.598094
# 6867        Zimbabwe  1990  3324.348171
#
# [6868 rows x 3 columns]

# %%
internet_df = internet_df.drop(columns = ['Value Footnotes'])
internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 8.	Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %% [markdown]
# 9.	Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 0.	Merge the two DataFrames to one. Merge **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`.
# 11.	Look at the first five rows of your new DataFrame to confirm it merged correctly.
# 12.	Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use = gdp_df.merge(internet_df, on=['Country', 'Year'], how='left')
gdp_and_internet_use.head(10)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2019     2065.036398                 NaN
# 1  Afghanistan  2018     2033.779002                 NaN
# 2  Afghanistan  2017     2058.383832                 NaN
# 3  Afghanistan  2016     2057.062164                 NaN
# 4  Afghanistan  2015     2068.265904                 NaN
# 5  Afghanistan  2014     2102.385234            6.390000
# 6  Afghanistan  2013     2116.465454            5.900000
# 7  Afghanistan  2012     2075.491747            5.454545
# 8  Afghanistan  2011     1904.559799            5.000000
# 9  Afghanistan  2010     1957.029338            4.000000

# %%
gdp_and_internet_use.tail(10)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6858  Zimbabwe  1999     3600.849291            0.161676
# 6859  Zimbabwe  1998     3653.920016            0.081648
# 6860  Zimbabwe  1997     3580.048793            0.033080
# 6861  Zimbabwe  1996     3520.430146            0.016790
# 6862  Zimbabwe  1995     3226.413930            0.007684
# 6863  Zimbabwe  1994     3263.934978            0.001739
# 6864  Zimbabwe  1993     3033.504852                 NaN
# 6865  Zimbabwe  1992     3054.889178                 NaN
# 6866  Zimbabwe  1991     3426.598094                 NaN
# 6867  Zimbabwe  1990     3324.348171            0.000000

# %% [markdown]
# 13.	Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
gdp_and_internet_use_3years = gdp_and_internet_use.loc[gdp_and_internet_use['Year'].isin[2004, 2009, 2014]]
gdp_and_internet_use_3years
#how to make this one work?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 gdp_and_internet_use_3years = gdp_and_internet_use.loc[gdp_and_internet_use['Year'].isin[2004, 2009, 2014]]
#       2 gdp_and_internet_use_3years
#
# TypeError: 'method' object is not subscriptable

# %%
years_list = [2004, 2009, 2014]
gdp_and_internet_use_3years = gdp_and_internet_use.query('Year in @years_list')
gdp_and_internet_use_3years
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5     Afghanistan  2014     2102.385234            6.390000
# 10    Afghanistan  2009     1758.904043            3.550000
# 15    Afghanistan  2004     1200.278256            0.105809
# 23        Albania  2014    11623.866679           60.100000
# 28        Albania  2009    10346.864199           41.200000
# ...           ...   ...             ...                 ...
# 6818       Zambia  2009     2917.516220            6.310000
# 6823       Zambia  2004     2261.766537            2.013550
# 6843     Zimbabwe  2014     2955.240287           19.890000
# 6848     Zimbabwe  2009     1925.364381           11.360000
# 6853     Zimbabwe  2004     2480.859342            6.564045
#
# [708 rows x 4 columns]

# %% [markdown]
# 14.	Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
gdp_and_internet_use_2004 = gdp_and_internet_use.loc[gdp_and_internet_use['Year'] == 2004]
gdp_and_internet_use_2004
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 15            Afghanistan  2004     1200.278256            0.105809
# 33                Albania  2004     7604.838002            2.420388
# 63                Algeria  2004    10058.435939            4.634475
# 93                 Angola  2004     5593.241537            0.464815
# 123   Antigua and Barbuda  2004    18745.681534           24.266544
# ...                   ...   ...             ...                 ...
# 6737              Vietnam  2004     3689.732423                 NaN
# 6767   West Bank and Gaza  2004     4485.525458                 NaN
# 6793                World  2004    12077.823821                 NaN
# 6823               Zambia  2004     2261.766537            2.013550
# 6853             Zimbabwe  2004     2480.859342            6.564045
#
# [234 rows x 4 columns]

# %%
gdp_and_internet_use_2009 = gdp_and_internet_use.loc[gdp_and_internet_use['Year'] == 2009]
gdp_and_internet_use_2009
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 10            Afghanistan  2009     1758.904043                3.55
# 28                Albania  2009    10346.864199               41.20
# 58                Algeria  2009    10782.361398               11.23
# 88                 Angola  2009     7643.493749                6.00
# 118   Antigua and Barbuda  2009    20046.839017               42.00
# ...                   ...   ...             ...                 ...
# 6732              Vietnam  2009     4830.304958                 NaN
# 6762   West Bank and Gaza  2009     5250.116075                 NaN
# 6788                World  2009    13396.524163                 NaN
# 6818               Zambia  2009     2917.516220                6.31
# 6848             Zimbabwe  2009     1925.364381               11.36
#
# [236 rows x 4 columns]

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use.loc[gdp_and_internet_use['Year'] == 2014]
gdp_and_internet_use_2014
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5             Afghanistan  2014     2102.385234                6.39
# 23                Albania  2014    11623.866679               60.10
# 53                Algeria  2014    11512.705405               18.09
# 83                 Angola  2014     8239.828837               21.26
# 113   Antigua and Barbuda  2014    18104.241470               64.00
# ...                   ...   ...             ...                 ...
# 6727              Vietnam  2014     6098.489609                 NaN
# 6757   West Bank and Gaza  2014     5967.073437                 NaN
# 6783                World  2014    15189.648507                 NaN
# 6813               Zambia  2014     3450.046561               17.34
# 6843             Zimbabwe  2014     2955.240287               19.89
#
# [238 rows x 4 columns]

# %% [markdown]
# 15.	Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).
# Iceland, 98.16%

# %%
#method 1
gdp_and_internet_use_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2625              Iceland  2014    49652.149500               98.16
# 561               Bermuda  2014    77361.104881               96.80
# 4648               Norway  2014    62589.373548               96.30
# 1452              Denmark  2014    52214.537753               95.99
# 3691           Luxembourg  2014   108760.916030               94.67
# ...                   ...   ...             ...                 ...
# 6427               Tuvalu  2014     3450.793169                 NaN
# 6607  Upper middle income  2014    14275.343977                 NaN
# 6727              Vietnam  2014     6098.489609                 NaN
# 6757   West Bank and Gaza  2014     5967.073437                 NaN
# 6783                World  2014    15189.648507                 NaN
#
# [238 rows x 4 columns]

# %%
#method 2
gdp_and_internet_use_2014.nlargest(1, 'Internet_Users_Pct')
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2625  Iceland  2014      49652.1495               98.16

# %% [markdown]
# 16.	Which country had the lowest percentage of internet users in 2014? What was the percentage?
# Timor-Leste, 1.14%

# %%
#method 1
gdp_and_internet_use_2014.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6219          Timor-Leste  2014     3264.568070                1.14
# 827               Burundi  2014      886.235777                1.38
# 2326               Guinea  2014     2061.760973                1.72
# 4528                Niger  2014     1127.615541                1.95
# 5434         Sierra Leone  2014     1997.511853                2.10
# ...                   ...   ...             ...                 ...
# 6427               Tuvalu  2014     3450.793169                 NaN
# 6607  Upper middle income  2014    14275.343977                 NaN
# 6727              Vietnam  2014     6098.489609                 NaN
# 6757   West Bank and Gaza  2014     5967.073437                 NaN
# 6783                World  2014    15189.648507                 NaN
#
# [238 rows x 4 columns]

# %%
#method 2
gdp_and_internet_use_2014.nsmallest(5, 'Internet_Users_Pct')
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6219  Timor-Leste  2014     3264.568070                1.14
# 827       Burundi  2014      886.235777                1.38
# 2326       Guinea  2014     2061.760973                1.72
# 4528        Niger  2014     1127.615541                1.95
# 4332      Myanmar  2014     4020.037369                2.10

# %% [markdown]
# 17.	Repeat for 2004 and 2009.

# %% [markdown]
# ### 2004
# Sweden - 83.89%
# Myanmar - 0.02%

# %%
gdp_and_internet_use_2004.nlargest(1, 'Internet_Users_Pct')
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6019  Sweden  2004    44496.023401               83.89

# %%
gdp_and_internet_use_2004.nsmallest(1, 'Internet_Users_Pct')
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4342  Myanmar  2004      1696.88176            0.024337

# %% [markdown]
# ### 2009
# Iceland - 93%
# Timor-Leste - 0.18%

# %%
gdp_and_internet_use_2009.nlargest(1, 'Internet_Users_Pct')
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2630  Iceland  2009    48177.084123                93.0

# %%
gdp_and_internet_use_2009.nsmallest(1, 'Internet_Users_Pct')
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6224  Timor-Leste  2009     2724.770973            0.185252

# %% [markdown]
# 18.	Which country had the highest gdp per capita in 2014? What was the gdp per capita?
# Hong Kong 156514.13385

# %%
gdp_and_internet_use_2014.nlargest(1,'GDP_Per_Capita')
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3721  Macao SAR, China  2014    156514.13385                 NaN

# %% [markdown]
# 20.	Which country had the lowest gdp per capita in 2014? What was the gdp per capita?
# Central African Republic 822.610458

# %%
gdp_and_internet_use_2014.nsmallest(1,'GDP_Per_Capita')
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1047  Central African Republic  2014      822.610458                 NaN

# %% [markdown]
# 	Create some scatterplots:
#     a.  2004 Percent Using the Internet vs GDP Per Capita

# %%
graphing_2004 = gdp_and_internet_use_2004.dropna(axis=0, how='any')
plt.scatter(graphing_2004.GDP_Per_Capita, graphing_2004.Internet_Users_Pct)
plt.xlabel('GDP Per Capita')
plt.ylabel('Percentage of Internet Users')
plt.title('GDP and Internet Users, 2004')
# Out:
# Text(0.5, 1.0, 'GDP and Internet Users, 2004')

# %%
graphing_2009 = gdp_and_internet_use_2009.dropna(axis=0, how='any')
plt.scatter(graphing_2009.GDP_Per_Capita, graphing_2009.Internet_Users_Pct)
plt.xlabel('GDP Per Capita')
plt.ylabel('Percentage of Internet Users')
plt.title('GDP and Internet Users, 2009')
# Out:
# Text(0.5, 1.0, 'GDP and Internet Users, 2009')

# %%
graphing_2014 = gdp_and_internet_use_2014.dropna(axis=0, how='any')
plt.scatter(graphing_2014.GDP_Per_Capita, graphing_2014.Internet_Users_Pct)
plt.xlabel('GDP Per Capita')
plt.ylabel('Percentage of Internet Users')
plt.title('GDP and Internet Users, 2014')
# Out:
# Text(0.5, 1.0, 'GDP and Internet Users, 2014')

# %% [markdown]
# 22.	Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.
#
# GDP and % of population on the internet appear to become much more strongly correlated between 2004 and 2014. By 2014 we no longer see countries with a very high GDP and very low internet usage, which did still exist in 2004.

# %% [markdown]
# 23.	Look at the distribution of gdp per capita values for 2014. Is it unimodal?
# Yes, skewed left

# %%
#gives list of all dataframes loaded into notebook. maybe it has to go last?
#who% DataFrame

# %%
gdp_2014 = gdp_df.loc[gdp_df['Year'] == 2014]
gdp_2014
plt.hist(gdp_2014.GDP_Per_Capita)
# Out:
# (array([146.,  41.,  25.,  18.,   4.,   1.,   2.,   0.,   0.,   1.]),
#  array([   822.61045782,  16391.76279701,  31960.91513621,  47530.06747541,
#          63099.2198146 ,  78668.3721538 ,  94237.524493  , 109806.67683219,
#         125375.82917139, 140944.98151059, 156514.13384978]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 24.	Look at the distribution of Internet Use for 2014. Is it unimodal?
# it's more bimodal than unimodal, with peaks at 0-20 % and 40-50 %

# %%
internet_2014 = internet_df.loc[internet_df['Year'] == 2014]
internet_2014
# Out:
#                     Country  Year  Internet_Users_Pct
# 0               Afghanistan  2014                6.39
# 15                  Albania  2014               60.10
# 36                  Algeria  2014               18.09
# 59                  Andorra  2014               95.90
# 78                   Angola  2014               21.26
# ...                     ...   ...                 ...
# 4389               Viet Nam  2014               48.31
# 4409  Virgin Islands (U.S.)  2014               50.07
# 4431                  Yemen  2014               22.55
# 4451                 Zambia  2014               17.34
# 4473               Zimbabwe  2014               19.89
#
# [202 rows x 3 columns]

# %%
plt.hist(internet_2014.Internet_Users_Pct)
# Out:
# (array([31., 31., 12., 10., 24., 18., 21., 20., 18., 17.]),
#  array([ 0.   ,  9.816, 19.632, 29.448, 39.264, 49.08 , 58.896, 68.712,
#         78.528, 88.344, 98.16 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 25.	What are the top 5 countries in terms of internet use in 2014?

# %%
internet_2014.nlargest(5, 'Internet_Users_Pct')
# Out:
#       Country  Year  Internet_Users_Pct
# 1866  Iceland  2014               98.16
# 415   Bermuda  2014               96.80
# 3016   Norway  2014               96.30
# 1083  Denmark  2014               95.99
# 59    Andorra  2014               95.90

# %%
whos% DataFrame
# Out:
# Variable                      Type         Data/Info
# ----------------------------------------------------
# gdp_2014                      DataFrame                      Country<...>n\n[238 rows x 3 columns]
# gdp_and_internet_use          DataFrame              Country  Year  <...>\n[6868 rows x 4 columns]
# gdp_and_internet_use_2004     DataFrame                      Country<...>n\n[234 rows x 4 columns]
# gdp_and_internet_use_2009     DataFrame                      Country<...>n\n[236 rows x 4 columns]
# gdp_and_internet_use_2014     DataFrame                      Country<...>n\n[238 rows x 4 columns]
# gdp_and_internet_use_3years   DataFrame              Country  Year  <...>n\n[708 rows x 4 columns]
# gdp_df                        DataFrame              Country  Year  <...>\n[6868 rows x 3 columns]
# graphing_2004                 DataFrame                      Country<...>n\n[157 rows x 4 columns]
# ...

# %% [markdown]
# 26.	Create a DataFrame called top_5_internet **from the combined DataFrame that has all three years _for the 5 countries that had the greatest 2014 internet usage_**. You should have 15 rows. Check that this is true.

# %%
#first try
countries = ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra']
top_5_countries = internet_df.query('Country in @countries')

years = [2004, 2009, 2014]
top_5_internet = top_5_countries.query('Year in @years & Country in @countries')
top_5_internet
# Out:
#       Country  Year  Internet_Users_Pct
# 59    Andorra  2014           95.900000
# 64    Andorra  2009           78.530000
# 69    Andorra  2004           26.837954
# 415   Bermuda  2014           96.800000
# 420   Bermuda  2009           83.250000
# 425   Bermuda  2004           60.990867
# 1083  Denmark  2014           95.990000
# 1088  Denmark  2009           86.840000
# 1093  Denmark  2004           80.930000
# 1866  Iceland  2014           98.160000
# 1871  Iceland  2009           93.000000
# 1876  Iceland  2004           83.880000
# 3016   Norway  2014           96.300000
# 3021   Norway  2009           92.080000
# 3026   Norway  2004           77.690000

# %%
#better way
countries_top_5 = internet_df.loc[internet_df['Country'].isin(['Andorra', 'Bermuda', 'Denmark', 'Iceland', 'Norway'])]
test = countries_top_5.loc[countries_top_5['Year'].isin([2004, 2009, 2014])]
test
#you can't have the ==, doesn't work with more than one value
#internet_df.loc[internet_df['Country'] == ['Andorra', 'Bermuda', 'Denmark', 'Iceland', 'Norway']]
# Out:
#       Country  Year  Internet_Users_Pct
# 59    Andorra  2014           95.900000
# 64    Andorra  2009           78.530000
# 69    Andorra  2004           26.837954
# 415   Bermuda  2014           96.800000
# 420   Bermuda  2009           83.250000
# 425   Bermuda  2004           60.990867
# 1083  Denmark  2014           95.990000
# 1088  Denmark  2009           86.840000
# 1093  Denmark  2004           80.930000
# 1866  Iceland  2014           98.160000
# 1871  Iceland  2009           93.000000
# 1876  Iceland  2004           83.880000
# 3016   Norway  2014           96.300000
# 3021   Norway  2009           92.080000
# 3026   Norway  2004           77.690000

# %%
#best way
countries = ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra']
years = [2004, 2009, 2014]
method3 = internet_df.query('Country in @countries & Year in @years')
#need &, comma doesn't work
method3
# Out:
#       Country  Year  Internet_Users_Pct
# 59    Andorra  2014           95.900000
# 64    Andorra  2009           78.530000
# 69    Andorra  2004           26.837954
# 415   Bermuda  2014           96.800000
# 420   Bermuda  2009           83.250000
# 425   Bermuda  2004           60.990867
# 1083  Denmark  2014           95.990000
# 1088  Denmark  2009           86.840000
# 1093  Denmark  2004           80.930000
# 1866  Iceland  2014           98.160000
# 1871  Iceland  2009           93.000000
# 1876  Iceland  2004           83.880000
# 3016   Norway  2014           96.300000
# 3021   Norway  2009           92.080000
# 3026   Norway  2004           77.690000

# %% [markdown]
# 27.	Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014?

# %% [markdown]
# g = sns.FacetGrid(tips, col="time",  row="sex")
# g.map_dataframe(sns.histplot, x="total_bill")

# %%
g = sns.FacetGrid(method3, col='Country')
g.map_dataframe(sns.barplot, x='Year', y='Internet_Users_Pct', data=method3, order=[2004, 2009, 2014])

# %% [markdown]
# 28.	Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use?

# %%
print(internet_2014.nsmallest(5, 'Internet_Users_Pct')) #I used internet_2014 here, not gdp_and_internet_use_2014 b/c the latter seems to only include countries with a GDP listed
# Out:
#                           Country  Year  Internet_Users_Pct
# 1065  Dem. People's Rep. of Korea  2014                0.00
# 1256                      Eritrea  2014                0.99
# 4019                  Timor-Leste  2014                1.14
# 623                       Burundi  2014                1.38
# 3648                      Somalia  2014                1.63

# %%
years = [2004, 2009, 2014]
countries = ["Dem. People's Rep. of Korea", "Eritrea", "Timor-Leste", "Burundi", "Somalia"]
bottom_5_internet = internet_df.query('Country in @countries & Year in @years')
bottom_5_internet
# Out:
#                           Country  Year  Internet_Users_Pct
# 623                       Burundi  2014            1.380000
# 628                       Burundi  2009            0.900000
# 633                       Burundi  2004            0.349060
# 1065  Dem. People's Rep. of Korea  2014            0.000000
# 1069  Dem. People's Rep. of Korea  2009            0.000000
# 1074  Dem. People's Rep. of Korea  2004            0.000000
# 1256                      Eritrea  2014            0.990000
# 1261                      Eritrea  2009            0.540000
# 3648                      Somalia  2014            1.630000
# 3652                      Somalia  2009            1.160611
# 3657                      Somalia  2004            1.053455
# 4019                  Timor-Leste  2014            1.140000
# 4024                  Timor-Leste  2009            0.185252

# %%
p = sns.FacetGrid(bottom_5_internet, col='Country')
p.map_dataframe(sns.barplot, x='Year', y='Internet_Users_Pct', data=bottom_5_internet, order=[2004, 2009, 2014])

# %% [markdown]
# 29.	Find the top 5 countries for 2014 in terms of GDP per capita; create a DataFrame to look at 10-year trends (use 2004, 2009, 2014 to look at the 10-year trend) in gdp per capita for the 5 countries with the highest 2014 GDP per capita. Use a seaborn facet grid for this.

# %%
whos% DataFrame
# Out:
# Variable                      Type         Data/Info
# ----------------------------------------------------
# bottom_5_internet             DataFrame                             <...> 2009            0.185252
# countries_top_5               DataFrame          Country  Year  Inte<...>n\n[115 rows x 3 columns]
# gdp_2014                      DataFrame                      Country<...>n\n[238 rows x 3 columns]
# gdp_and_internet_use          DataFrame              Country  Year  <...>\n[6868 rows x 4 columns]
# gdp_and_internet_use_2004     DataFrame                      Country<...>n\n[234 rows x 4 columns]
# gdp_and_internet_use_2009     DataFrame                      Country<...>n\n[236 rows x 4 columns]
# gdp_and_internet_use_2014     DataFrame                      Country<...>n\n[238 rows x 4 columns]
# gdp_and_internet_use_3years   DataFrame              Country  Year  <...>n\n[708 rows x 4 columns]
# ...

# %%
gdp_2014.nlargest(5, 'GDP_Per_Capita')
# Out:
#                Country  Year  GDP_Per_Capita
# 3721  Macao SAR, China  2014   156514.133850
# 3691        Luxembourg  2014   108760.916030
# 5138             Qatar  2014    95578.416973
# 5464         Singapore  2014    87808.663157
# 561            Bermuda  2014    77361.104881
# 1033    Cayman Islands  2014    66207.447230

# %%
years = [2004, 2009, 2014]
countries = ['Macao SAR, China', 'Luxembourg', 'Qatar', 'Singapore', 'Bermuda']
top_5_GDP = gdp_df.query('Year in @years & Country in @countries')
top_5_GDP
# Out:
#                Country  Year  GDP_Per_Capita
# 561            Bermuda  2014    77361.104881
# 566            Bermuda  2009    89961.982744
# 571            Bermuda  2004    90195.811033
# 3691        Luxembourg  2014   108760.916030
# 3696        Luxembourg  2009   104932.811953
# 3701        Luxembourg  2004   102708.212547
# 3721  Macao SAR, China  2014   156514.133850
# 3726  Macao SAR, China  2009    95939.340822
# 3731  Macao SAR, China  2004    72944.409424
# 5138             Qatar  2014    95578.416973
# 5143             Qatar  2009    89954.519993
# 5148             Qatar  2004    93748.301216
# 5464         Singapore  2014    87808.663157
# 5469         Singapore  2009    69466.581746
# 5474         Singapore  2004    63901.716368

# %%
rich_guys = sns.FacetGrid(top_5_GDP, col='Country')
rich_guys.map_dataframe(sns.lineplot, data=top_5_GDP, x='Year', y='GDP_Per_Capita')

# %% [markdown]
# 96. Repeat this one more time to look at 10-year trend for the 5 countries for 2014 with the lowest GDP per capita.

# %%
gdp_2014.nsmallest(5, 'GDP_Per_Capita')
# Out:
#                        Country  Year  GDP_Per_Capita
# 1047  Central African Republic  2014      822.610458
# 827                    Burundi  2014      886.235777
# 3781                    Malawi  2014     1027.208496
# 1422           Dem. Rep. Congo  2014     1029.790785
# 4528                     Niger  2014     1127.615541

# %%
years = [2004, 2009, 2014]
countries = ['Central African Republic', 'Burundi', 'Malawi', 'Dem. Rep. Congo', 'Niger']
bottom_5_GDP = gdp_df.query('Year in @years & Country in @countries')
bottom_5_GDP
# Out:
#                        Country  Year  GDP_Per_Capita
# 827                    Burundi  2014      886.235777
# 832                    Burundi  2009      831.564131
# 837                    Burundi  2004      817.460585
# 1047  Central African Republic  2014      822.610458
# 1052  Central African Republic  2009     1161.189475
# 1057  Central African Republic  2004     1037.846766
# 1422           Dem. Rep. Congo  2014     1029.790785
# 1427           Dem. Rep. Congo  2009      835.611696
# 1432           Dem. Rep. Congo  2004      757.685942
# 3781                    Malawi  2014     1027.208496
# 3786                    Malawi  2009      932.867635
# 3791                    Malawi  2004      775.346132
# 4528                     Niger  2014     1127.615541
# 4533                     Niger  2009      992.409977
# 4538                     Niger  2004      929.883920

# %%
poor_guys = sns.FacetGrid(bottom_5_GDP, col='Country')
poor_guys.map_dataframe(sns.lineplot, data=bottom_5_GDP, x='Year', y='GDP_Per_Capita')
